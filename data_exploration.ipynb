# %% [markdown]
# # Package Import

# %%
import dask.dataframe as dd
import os
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.impute import SimpleImputer
import pandas as pd

# %%
path = 'C:/Eigene Dateien/Masterarbeit/FraudDetection/Daten/tx_out_filesplit/'
os.chdir(path)

# %% [markdown]
# # Read data, check nulls, upsample and encode

# %%
df = dd.read_parquet('final_data_set')
df = df.set_index('address')
df_illicit = df[df['illicit'] == 1]
df_licit = df[df['illicit'] == 0]
df.head()
# Out:
#                                     count_addresses  count_addresses_sender  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                3                       2
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ              271                       2
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                7                       2
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                6                       3
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt             2424                     303
#
#                                     count_addresses_receiver  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                         2
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                       269
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                         6
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                         4
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                      2148
#
#                                     count_transactions  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                   2
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                   2
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                   2
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                   2
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                 118
#
#                                     count_transactions_sender  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                        1.0
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                        NaN
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                        1.0
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                        1.0
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                       51.0
#
#                                     count_transactions_receiver  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                            1
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                            2
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                            1
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                            1
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                           67
#
#                                     count_transactions_s_equal_r  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                           0.0
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                           NaN
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                           0.0
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                           0.0
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                           0.0
#
#                                     darknet_markets  lifetime  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX             61.0         1
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ             54.1         6
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY             59.0         1
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4             42.5        91
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt             42.9       151
#
#                                     min_transaction_value  ...  \
# address                                                    ...
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX               0.013723  ...
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ               0.000007  ...
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY               0.193508  ...
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4               0.000026  ...
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt               0.000090  ...
#
#                                     mean_transactions_fee  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX               0.000042
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ               0.000046
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY               0.000022
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4               0.000236
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt               0.000973
#
#                                     mean_transactions_fee_sender  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                      0.000033
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                           NaN
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                      0.000031
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                      0.000045
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                      0.000616
#
#                                     mean_transactions_fee_receiver  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                        0.000052
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                        0.000046
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                        0.000013
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                        0.000426
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                        0.001245
#
#                                     mean_transactions_volume  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                  0.013723
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                  0.000012
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                  0.193508
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                  0.000026
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                  0.493333
#
#                                     mean_transactions_volume_sender  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                         0.013723
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                              NaN
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                         0.193508
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                         0.000026
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                         0.570716
#
#                                     mean_transactions_volume_receiver  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                           0.013723
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                           0.000012
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                           0.193508
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                           0.000026
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                           0.434429
#
#                                     concentration_addresses  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                -1.000000
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ              -269.000000
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                -5.000000
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                -4.000000
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt               -19.709402
#
#                                     concentration_addresses_sender  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                            1.00
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                             NaN
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                            1.00
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                            1.00
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                           -5.04
#
#                                     concentration_addresses_receiver  illicit
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                          1.000000        0
# 1122LfQRzJdC31Tw9h8XyBRqT7QUM9yKrZ                       -267.000000        0
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                          1.000000        0
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                          1.000000        0
# 1123LLCPfHznjsYh4exJbkyiUAfkC7pbAt                        -31.530303        0
#
# [5 rows x 61 columns]

# %% [markdown]
# Check if null values

# %%
df_is_null = df.isnull().sum().reset_index()
df_is_null = df_is_null[df_is_null[0] > 0]
df_is_null = df_is_null.rename(columns = {'index': 'feature is null', 0: 'count'})
df_is_null.compute()
# Out:
#                            feature is null   count
# 4                count_transactions_sender   16510
# 6             count_transactions_s_equal_r   16510
# 11                   std_transaction_value   14946
# 12            min_transaction_value_sender   16510
# 13            max_transaction_value_sender   16510
# 14            std_transaction_value_sender  239719
# 17          std_transaction_value_receiver  236633
# 19                             std_balance   14851
# 23    std_addresses_per_transaction_sender   14837
# 27  std_addresses_per_transaction_receiver   14837
# 31           std_addresses_per_transaction   14837
# 33           transaction_volume_sender_btc   16510
# 36          transaction_volume_sender_euro   16510
# 39                  transaction_fee_sender   16510
# 41              mean_time_diff_transaction   14837
# 42               std_time_diff_transaction  237273
# 43       mean_time_diff_transaction_sender  239635
# 44        std_time_diff_transaction_sender  250474
# 45     mean_time_diff_transaction_receiver  236532
# 46      std_time_diff_transaction_receiver  248931
# 48                mean_transactions_sender   16510
# 50             mean_transactions_s_equal_r   16511
# 52            mean_transactions_fee_sender   16510
# 55         mean_transactions_volume_sender   16510
# 58          concentration_addresses_sender   16510

# %% [markdown]
# Closer look to the feature count_transactions_sender is null values. To make assumptions to other features. (Left: count_transactions_sender feature columns Right: original dataframe)

# %%
df_is_null_1 = df[df['count_transactions_sender'].isnull()].isnull().sum().reset_index()
df_is_null_1 = dd.concat([df_is_null_1[df_is_null_1[0] > 0], df_is_null], axis = 1)
df_is_null_1.compute()
# Out:
# C:\Anaconda\anaconda3\envs\fraud\lib\site-packages\dask\dataframe\multi.py:1291: UserWarning: Concatenating dataframes with unknown divisions.
# We're assuming that the indices of each dataframes are
#  aligned. This assumption is not generally safe.
#   warnings.warn(
#                                      index      0  \
# 4                count_transactions_sender  16510
# 6             count_transactions_s_equal_r  16510
# 11                   std_transaction_value  14851
# 12            min_transaction_value_sender  16510
# 13            max_transaction_value_sender  16510
# 14            std_transaction_value_sender  16510
# 17          std_transaction_value_receiver  14851
# 19                             std_balance  14848
# 23    std_addresses_per_transaction_sender  14837
# 27  std_addresses_per_transaction_receiver  14837
# 31           std_addresses_per_transaction  14837
# 33           transaction_volume_sender_btc  16510
# 36          transaction_volume_sender_euro  16510
# 39                  transaction_fee_sender  16510
# 41              mean_time_diff_transaction  14837
# 42               std_time_diff_transaction  15578
# 43       mean_time_diff_transaction_sender  16510
# 44        std_time_diff_transaction_sender  16510
# 45     mean_time_diff_transaction_receiver  14837
# 46      std_time_diff_transaction_receiver  15578
# 48                mean_transactions_sender  16510
# 50             mean_transactions_s_equal_r  16510
# 52            mean_transactions_fee_sender  16510
# 55         mean_transactions_volume_sender  16510
# 58          concentration_addresses_sender  16510
#
#                            feature is null   count
# 4                count_transactions_sender   16510
# 6             count_transactions_s_equal_r   16510
# 11                   std_transaction_value   14946
# 12            min_transaction_value_sender   16510
# 13            max_transaction_value_sender   16510
# 14            std_transaction_value_sender  239719
# 17          std_transaction_value_receiver  236633
# 19                             std_balance   14851
# 23    std_addresses_per_transaction_sender   14837
# 27  std_addresses_per_transaction_receiver   14837
# 31           std_addresses_per_transaction   14837
# 33           transaction_volume_sender_btc   16510
# 36          transaction_volume_sender_euro   16510
# 39                  transaction_fee_sender   16510
# 41              mean_time_diff_transaction   14837
# 42               std_time_diff_transaction  237273
# 43       mean_time_diff_transaction_sender  239635
# 44        std_time_diff_transaction_sender  250474
# 45     mean_time_diff_transaction_receiver  236532
# 46      std_time_diff_transaction_receiver  248931
# 48                mean_transactions_sender   16510
# 50             mean_transactions_s_equal_r   16511
# 52            mean_transactions_fee_sender   16510
# 55         mean_transactions_volume_sender   16510
# 58          concentration_addresses_sender   16510

# %% [markdown]
# The null values appeared because of missing sender transactions. Therefore a imputation with 0 is suitable.

# %%
df_is_null_1[df_is_null_1['index'].str.contains('sender')].compute()
# Out:
#                                    index      0  \
# 4              count_transactions_sender  16510
# 12          min_transaction_value_sender  16510
# 13          max_transaction_value_sender  16510
# 14          std_transaction_value_sender  16510
# 23  std_addresses_per_transaction_sender  14837
# 33         transaction_volume_sender_btc  16510
# 36        transaction_volume_sender_euro  16510
# 39                transaction_fee_sender  16510
# 43     mean_time_diff_transaction_sender  16510
# 44      std_time_diff_transaction_sender  16510
# 48              mean_transactions_sender  16510
# 52          mean_transactions_fee_sender  16510
# 55       mean_transactions_volume_sender  16510
# 58        concentration_addresses_sender  16510
#
#                          feature is null   count
# 4              count_transactions_sender   16510
# 12          min_transaction_value_sender   16510
# 13          max_transaction_value_sender   16510
# 14          std_transaction_value_sender  239719
# 23  std_addresses_per_transaction_sender   14837
# 33         transaction_volume_sender_btc   16510
# 36        transaction_volume_sender_euro   16510
# 39                transaction_fee_sender   16510
# 43     mean_time_diff_transaction_sender  239635
# 44      std_time_diff_transaction_sender  250474
# 48              mean_transactions_sender   16510
# 52          mean_transactions_fee_sender   16510
# 55       mean_transactions_volume_sender   16510
# 58        concentration_addresses_sender   16510

# %%
df_is_null_1[~df_is_null_1['index'].str.contains('sender')].compute()
# Out:
#                                      index      0  \
# 6             count_transactions_s_equal_r  16510
# 11                   std_transaction_value  14851
# 17          std_transaction_value_receiver  14851
# 19                             std_balance  14848
# 27  std_addresses_per_transaction_receiver  14837
# 31           std_addresses_per_transaction  14837
# 41              mean_time_diff_transaction  14837
# 42               std_time_diff_transaction  15578
# 45     mean_time_diff_transaction_receiver  14837
# 46      std_time_diff_transaction_receiver  15578
# 50             mean_transactions_s_equal_r  16510
#
#                            feature is null   count
# 6             count_transactions_s_equal_r   16510
# 11                   std_transaction_value   14946
# 17          std_transaction_value_receiver  236633
# 19                             std_balance   14851
# 27  std_addresses_per_transaction_receiver   14837
# 31           std_addresses_per_transaction   14837
# 41              mean_time_diff_transaction   14837
# 42               std_time_diff_transaction  237273
# 45     mean_time_diff_transaction_receiver  236532
# 46      std_time_diff_transaction_receiver  248931
# 50             mean_transactions_s_equal_r   16511

# %% [markdown]
# "count_transactions_s_equal_r" and "mean_transactions_s_equal_r" compare sender and receiver. If there are no senders, there is nothing to compare. Therefore 0 is imputed.

# %%
rest_isnull = df_is_null[~(df_is_null_1['index'].str.contains('sender') | df_is_null_1['index'].str.contains('s_equal_r'))]
rest_isnull.compute()
# Out:
#                            feature is null   count
# 11                   std_transaction_value   14946
# 17          std_transaction_value_receiver  236633
# 19                             std_balance   14851
# 27  std_addresses_per_transaction_receiver   14837
# 31           std_addresses_per_transaction   14837
# 41              mean_time_diff_transaction   14837
# 42               std_time_diff_transaction  237273
# 45     mean_time_diff_transaction_receiver  236532
# 46      std_time_diff_transaction_receiver  248931

# %% [markdown]
# 'time_diff' can be nan if there is only one transaction. Same is if the standard deviation is calculated but there is only one transaction (correction term of the standard deviation n-1 results in 0 division). Therefore std_transaction_value, std_balance, std_addresses_per_transaction_receiver, std_addresses_per_transaction and mean_time_diff_transaction can be imputed with 0

# %%
(df[df['std_transaction_value'].isnull()]['count_transactions'] == 1).sum().compute()
# Out:
# 14837

# %% [markdown]
# The same problem with receiver transactions which are 0. Therefore std_transaction_value_receiver, mean_time_diff_transaction_receiver and std_time_diff_transaction_receiver can be imputed with 0.

# %%
(df[df['std_transaction_value_receiver'].isnull()]['count_transactions_receiver'] == 1).sum().compute()
# Out:
# 236536

# %%
df[df['std_transaction_value_receiver'].isnull()][['count_transactions_receiver', 'std_transaction_value_receiver']].head()
# Out:
#                                     count_transactions_receiver  \
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                            1
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                            1
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                            1
# 1124Vc7iWXAWYjJqexhwi2oxMnbfxppvRd                            1
# 1125oHW3KCah1esMomGda4kPqLYcQcfmfT                            1
#
#                                     std_transaction_value_receiver
# address
# 1121fvgKUFNeBmVSLLcPaNS8TtWn4GrZdX                             NaN
# 1122Mgd8GnaBcBv6gJ5QcvKt76GqGsRvjY                             NaN
# 11239Kbtbp9v6iQa7NhFFiZ4ByhKLwThq4                             NaN
# 1124Vc7iWXAWYjJqexhwi2oxMnbfxppvRd                             NaN
# 1125oHW3KCah1esMomGda4kPqLYcQcfmfT                             NaN

# %%
df[((df['std_transaction_value_receiver'].isnull()) & (df['std_transaction_value_receiver'] > 1))].compute()
# Out:
# Empty DataFrame
# Columns: [count_addresses, count_addresses_sender, count_addresses_receiver, count_transactions, count_transactions_sender, count_transactions_receiver, count_transactions_s_equal_r, darknet_markets, lifetime, min_transaction_value, max_transaction_value, std_transaction_value, min_transaction_value_sender, max_transaction_value_sender, std_transaction_value_sender, min_transaction_value_receiver, max_transaction_value_receiver, std_transaction_value_receiver, mean_balance, std_balance, mean_addresses_per_transaction_sender, min_addresses_per_transaction_sender, max_addresses_per_transaction_sender, std_addresses_per_transaction_sender, mean_addresses_per_transaction_receiver, min_addresses_per_transaction_receiver, max_addresses_perr_transaction_receiver, std_addresses_per_transaction_receiver, mean_addresses_per_transaction, min_addresses_per_transaction, max_addresses_per_transaction, std_addresses_per_transaction, transaction_volume_btc, transaction_volume_sender_btc, transaction_volume_receiver_btc, transaction_volume_euro, transaction_volume_sender_euro, transaction_volume_receiver_euro, transaction_fee, transaction_fee_sender, transaction_fee_receiver, mean_time_diff_transaction, std_time_diff_transaction, mean_time_diff_transaction_sender, std_time_diff_transaction_sender, mean_time_diff_transaction_receiver, std_time_diff_transaction_receiver, mean_transactions, mean_transactions_sender, mean_transactions_receiver, mean_transactions_s_equal_r, mean_transactions_fee, mean_transactions_fee_sender, mean_transactions_fee_receiver, mean_transactions_volume, mean_transactions_volume_sender, mean_transactions_volume_receiver, concentration_addresses, concentration_addresses_sender, concentration_addresses_receiver, illicit]
# Index: []
#
# [0 rows x 61 columns]

# %% [markdown]
# Conclusion to null-values: mostly a result of no transactions in this category or only one transaction. Therefore imputation of 0 for null values is suggested.

# %% [markdown]
# Upsample

# %%
df_illicit = df_illicit.sample(frac = 3.876,
                               replace = True,
                               random_state = 190)

# %% [markdown]
# Check if upsampled data contains all illicit addresses. The sample method doesn't gurantee for it. Therefore the missing entries were added manually.

# %%
len(df[df['illicit'] == 1].index.unique())
# Out:
# 13561

# %%
len(df_illicit.index.unique())
# Out:
# 13312

# %%
len(df_illicit.index)
# Out:
# 52595

# %%
index_df = df_illicit.index.unique().compute()
df_1 = df[df['illicit'] == 1].compute()
df_1 = df_1[~df_1.index.isin(index_df)]
df_1
# Out:
# ...                                                                       ...
# 3QpNHy9GjNxGp3VXKeh8hEJMxMUSayYkGh                                   0.018048
# 3QsLNUptraBrHt8SPgHRZkYHcBuigtADcg                                   0.000523
# 3Qu3sQREAMT6gKR94CihDkLeeKyXT7A2EJ                                   0.168764
# 3QyjuxejZuBRkpP7HhovEvnUET4o47J8c8                                   0.016708
# bc1qvcq348wsgzfwqtv57gswhsjjjv7jtuyexf8ppk                           0.032098
#
#                                             concentration_addresses  \
# address
# 126DFo5prJxqBv48ZPRjCoHb3mxkHViqjx                       -66.294118
# 1271BQNWeDc8CpWgirPjgVeHmJss8Y5tsj                      -151.166667
# 13KVgnAeh2afikNT22ZgtcsTETdRLmHgQf                      -253.000000
# 13c1qs8kgQg6u8xQPsLwy37Wd4ovZweBwR                        -8.447806
# 13w2fsyT97RoE1E7jjoVDwrzXoztgPTchZ                         1.000000
# ...                                                             ...
# 3QpNHy9GjNxGp3VXKeh8hEJMxMUSayYkGh                       -17.000000
# 3QsLNUptraBrHt8SPgHRZkYHcBuigtADcg                         1.000000
# 3Qu3sQREAMT6gKR94CihDkLeeKyXT7A2EJ                        -6.000000
# 3QyjuxejZuBRkpP7HhovEvnUET4o47J8c8                        -5.000000
# bc1qvcq348wsgzfwqtv57gswhsjjjv7jtuyexf8ppk               -10.981818
#
#                                             concentration_addresses_sender  \
# address
# 126DFo5prJxqBv48ZPRjCoHb3mxkHViqjx                             -118.428571
# 1271BQNWeDc8CpWgirPjgVeHmJss8Y5tsj                             -234.000000
# 13KVgnAeh2afikNT22ZgtcsTETdRLmHgQf                                1.000000
# 13c1qs8kgQg6u8xQPsLwy37Wd4ovZweBwR                               -5.121212
# 13w2fsyT97RoE1E7jjoVDwrzXoztgPTchZ                                     NaN
# ...                                                                    ...
# 3QpNHy9GjNxGp3VXKeh8hEJMxMUSayYkGh                                1.000000
# 3QsLNUptraBrHt8SPgHRZkYHcBuigtADcg                                     NaN
# 3Qu3sQREAMT6gKR94CihDkLeeKyXT7A2EJ                                1.000000
# 3QyjuxejZuBRkpP7HhovEvnUET4o47J8c8                                1.000000
# bc1qvcq348wsgzfwqtv57gswhsjjjv7jtuyexf8ppk                        0.961538
#
#                                             concentration_addresses_receiver  \
# address
# 126DFo5prJxqBv48ZPRjCoHb3mxkHViqjx                                -33.333333
# 1271BQNWeDc8CpWgirPjgVeHmJss8Y5tsj                               -121.166667
# 13KVgnAeh2afikNT22ZgtcsTETdRLmHgQf                                  1.000000
# 13c1qs8kgQg6u8xQPsLwy37Wd4ovZweBwR                                -10.959596
# 13w2fsyT97RoE1E7jjoVDwrzXoztgPTchZ                                  1.000000
# ...                                                                      ...
# 3QpNHy9GjNxGp3VXKeh8hEJMxMUSayYkGh                                  1.000000
# 3QsLNUptraBrHt8SPgHRZkYHcBuigtADcg                                  1.000000
# 3Qu3sQREAMT6gKR94CihDkLeeKyXT7A2EJ                                  1.000000
# 3QyjuxejZuBRkpP7HhovEvnUET4o47J8c8                                  1.000000
# bc1qvcq348wsgzfwqtv57gswhsjjjv7jtuyexf8ppk                        -11.166667
#
#                                             illicit
# address
# 126DFo5prJxqBv48ZPRjCoHb3mxkHViqjx                1
# 1271BQNWeDc8CpWgirPjgVeHmJss8Y5tsj                1
# 13KVgnAeh2afikNT22ZgtcsTETdRLmHgQf                1
# 13c1qs8kgQg6u8xQPsLwy37Wd4ovZweBwR                1
# 13w2fsyT97RoE1E7jjoVDwrzXoztgPTchZ                1
# ...                                             ...
# 3QpNHy9GjNxGp3VXKeh8hEJMxMUSayYkGh                1
# 3QsLNUptraBrHt8SPgHRZkYHcBuigtADcg                1
# 3Qu3sQREAMT6gKR94CihDkLeeKyXT7A2EJ                1
# 3QyjuxejZuBRkpP7HhovEvnUET4o47J8c8                1
# bc1qvcq348wsgzfwqtv57gswhsjjjv7jtuyexf8ppk        1
#
# [249 rows x 61 columns]

# %%
df_ml = dd.concat([df_licit, df_illicit, df_1], axis = 0)
len(df_ml.index.unique())
# Out:
# 264139

# %%
len(df_ml.index)

# %%
df_ml_features = df_ml.iloc[:, :-1]
df_ml_target = df_ml.iloc[:, [-1]]

# %% [markdown]
# Encoding

# %%
SimpleImputer(strategy='constant', fill_value=0).fit_transform(X = df_ml_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 SimpleImputer(strategy='constant', fill_value=0).fit_transform(X = df_ml_features, y = df_ml_target)
#
# File C:\Anaconda\anaconda3\envs\fraud\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File C:\Anaconda\anaconda3\envs\fraud\lib\site-packages\sklearn\base.py:918, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     915     return self.fit(X, **fit_params).transform(X)
#     916 else:
#     917     # fit method of arity 2 (supervised transformation)
# --> 918     return self.fit(X, y, **fit_params).transform(X)
#
# File C:\Anaconda\anaconda3\envs\fraud\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File C:\Anaconda\anaconda3\envs\fraud\lib\site-packages\sklearn\impute\_base.py:366, in SimpleImputer.fit(self, X, y)
#     348 @_fit_context(prefer_skip_nested_validation=True)
#     349 def fit(self, X, y=None):
#     350     """Fit the imputer on `X`.
#     351
#     352     Parameters
#    (...)
#     364         Fitted estimator.
#     365     """
# --> 366     X = self._validate_input(X, in_fit=True)
#     368     # default fill_value is 0 for numerical input and "missing_value"
#     369     # otherwise
#     370     if self.fill_value is None:
#
# File C:\Anaconda\anaconda3\envs\fraud\lib\site-packages\sklearn\impute\_base.py:329, in SimpleImputer._validate_input(self, X, in_fit)
#     327         raise new_ve from None
#     328     else:
# --> 329         raise ve
#     331 if in_fit:
#     332     # Use the dtype seen in `fit` for non-`fit` conversion
#     333     self._fit_dtype = X.dtype
#
# File C:\Anaconda\anaconda3\envs\fraud\lib\site-packages\sklearn\impute\_base.py:312, in SimpleImputer._validate_input(self, X, in_fit)
#     309     force_all_finite = True
#     311 try:
# --> 312     X = self._validate_data(
#     313         X,
#     314         reset=in_fit,
#     315         accept_sparse="csc",
#     316         dtype=dtype,
#     317         force_all_finite=force_all_finite,
#     318         copy=self.copy,
#     319     )
#     320 except ValueError as ve:
#     321     if "could not convert" in str(ve):
#
# File C:\Anaconda\anaconda3\envs\fraud\lib\site-packages\sklearn\base.py:604, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     602         out = X, y
#     603 elif not no_val_X and no_val_y:
# --> 604     out = check_array(X, input_name="X", **check_params)
#     605 elif no_val_X and not no_val_y:
#     606     out = _check_y(y, **check_params)
#
# File C:\Anaconda\anaconda3\envs\fraud\lib\site-packages\sklearn\utils\validation.py:959, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     953         raise ValueError(
#     954             "Found array with dim %d. %s expected <= 2."
#     955             % (array.ndim, estimator_name)
#     956         )
#     958     if force_all_finite:
# --> 959         _assert_all_finite(
#     960             array,
#     961             input_name=input_name,
#     962             estimator_name=estimator_name,
#     963             allow_nan=force_all_finite == "allow-nan",
#     964         )
#     966 if ensure_min_samples > 0:
#     967     n_samples = _num_samples(array)
#
# File C:\Anaconda\anaconda3\envs\fraud\lib\site-packages\sklearn\utils\validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File C:\Anaconda\anaconda3\envs\fraud\lib\site-packages\sklearn\utils\validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input X contains infinity or a value too large for dtype('float64').

# %%
num_pipeline = make_pipeline(SimpleImputer(strategy='constant', fill_value=0, copy=False))
num_pipeline.fit_transform(df_ml.iloc[:, 1:])

# %%
num_attribs = df_ml.iloc[:, 1:].columns

num_pipeline = make_pipeline(SimpleImputer(strategy='constant', fill_value=0, copy=False),
                             StandardScaler())

preprocessing = make_column_transformer((num_pipeline, num_attribs), remainder = 'passthrough').set_output(transform="pandas")

df_encoded = preprocessing.fit_transform(df_ml.iloc[:, 1:])

# %%
num_attribs = df_ml.iloc[:, 1:].columns

num_pipeline = make_pipeline('standardscaler', StandardScaler())

preprocessing = make_column_transformer( 
        (num_pipeline, num_attribs))

df_encoded = preprocessing.fit_transform(df.iloc[:, :-1], 
                                         df.iloc[:, -1])

df_encoded_upsample = preprocessing.fit_transform(df_ml.iloc[:, :-1], 
                                                  df_ml.iloc[:, -1])

# %% [markdown]
# # General

# %%
print(df.info())
print(df.describe())

# %% [markdown]
# # Pairplots

# %%
sns.pairplot(plot_set, 
             markers='o', 
             hue='illicit', 
             plot_kws={'alpha' : 0.25})
plt.show()

# %% [markdown]
# # Complete correlation

# %%
corr_all = df.corr()

vmax = np.round(corr.iloc[:-1, -1].abs().sort_values(ascending = False).head(1)[0], 1)

ax = sns.heatmap(corr, 
                 vmax = vmax, 
                 center = 0)

# %% [markdown]
# # Correlation with target variable

# %%
highlight_val = np.concatenate([corr_all['illicit'].head(3).values, corr_all['illicit'].tail(4).values], axis = 0)
colors = ['cornflowerblue' if i not in highlight_val else 'lightgreen' if i in highlight_val and i > 0 else 'lightcoral' for i in corrs[:-1]]

plt.bar(corr_all['illicit'].index, corr_all['illicit'], color = colors)
plt.title("Correlation between the features and 'credit rating'")
plt.xticks(rotation = 90)
plt.show()
